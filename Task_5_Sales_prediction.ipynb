# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalamana-Sirisha/OIBSIP_domain_taskno/blob/main/Task_5_Sales_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the dataset into pandas dataframe
dfads = pd.read_csv('/content/Advertising.csv')
type(dfads)
# Out:
# pandas.core.frame.DataFrame

# %%
dfads.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
dfads=dfads.drop(columns=["Unnamed: 0"])
dfads.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
dfads.shape
# Out:
# (200, 4)

# %%
dfads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
dfads.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
dfads.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#Correlation Matrix
dfads.corr(numeric_only=True)
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
#display the correlation matrix using heatmap
corr = dfads.corr(numeric_only=True)
fig,ax=plt.subplots(figsize=(8,6))
#compute the correlation matrix and plot it
sns.heatmap(corr,annot=True,ax=ax,cmap="viridis")
# Out:
# <Axes: >

# %%
#Data Visualization
#Scatter plots to check the linearity assumption between each independent variable(Tv,Radio,Newpaper)and the dependent variable(sales)
sns.pairplot(data = dfads,x_vars=['TV',"Radio","Newspaper"],y_vars='Sales',kind="reg",palette="pastel")
plt.show()

# %%
#scatterplot
plt.figure(figsize=(12,5))
columns = {0: "TV",1:"Radio",2:"Newspaper"}
for plot,col_name in columns.items():
  plt.subplot(1,3,plot+1)
  sns.scatterplot(x=dfads[col_name],y=dfads["Sales"],label=col_name,palette="pastel")
  plt.xlabel("{} VS Sales".format(col_name))
  plt.title("Scatter plot: {} VS Sales".format(col_name))
  plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
columns = {0: "TV",1: "Radio",2: "Newspaper"}
for plot,col_name in columns.items():
  plt.subplot(1 ,3, plot + 1)
  sns.distplot(x = dfads[col_name],hist=False,label=col_name)
  sns.distplot(x = dfads["Sales"],hist=False,label="Sales")
  plt.xlabel("{} VS Sales".format(col_name))
  plt.title("Distribution plot {} VS Sales".format(col_name))
  plt.legend()
plt.tight_layout()
plt.show()

# %%
#Histplot(Histogram plot)
dfads.hist()
plt.show()

# %%
#Linear regression plot
sns.lmplot(x="TV",y="Sales",data=dfads,height=5)
sns.lmplot(x="Radio",y="Sales",data=dfads,height=5)
sns.lmplot(x="Newspaper",y="Sales",data=dfads,height=5)

# %%
dfads
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dfads['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfads['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfads['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfads['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dfads.plot(kind='scatter', x='TV', y='Radio', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfads.plot(kind='scatter', x='Radio', y='Newspaper', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfads.plot(kind='scatter', x='Newspaper', y='Sales', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dfads['TV'].plot(kind='line', figsize=(8, 4), title='TV')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dfads['Radio'].plot(kind='line', figsize=(8, 4), title='Radio')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dfads['Newspaper'].plot(kind='line', figsize=(8, 4), title='Newspaper')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dfads['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#Preprocessing the dataset & model preparation
#checking for null values
dfads.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x=dfads.drop('Sales',axis=1)
y=dfads['Sales']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#LabelEncoder
from sklearn.preprocessing import MinMaxScaler,LabelEncoder,StandardScaler
lab=LabelEncoder()
y=lab.fit_transform(y)

# %%
#StandardScaler() standrdize feattures by removing the mean and scalling to unit variance
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(x)
print(x)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
print("Accuracy (Linear Regression):",model.score(x_test,y_test)*100)
# Out:
# Accuracy (Linear Regression): 89.9438024100912

# %%
#Lineplot
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
cv_scores=cross_val_score(model,x_train,y_train,cv=5,scoring='r2')
print("Linear Regression")
print("Mean squared error {}".format(mse))
print("R2 Score: {}".format(r2))
print("Cross Validation R2: {}".format(cv_scores.mean()))

plt.figure(figsize=(10,6))
plt.plot(np.arange(len(y_test)),y_test,label='Actual Trend')
plt.plot(np.arange(len(y_test)),y_pred,label='Predicted Trend')
plt.xlabel('Data Index')
plt.ylabel('Trend')
plt.title('Linear Regression : Actual Trend vs. Predicted Trend')
plt.legend()
plt.show()
# Out:
# Linear Regression
# Mean squared error 3.1740973539761033
# R2 Score: 0.899438024100912
# Cross Validation R2: 0.8594884313276513

# %%
#Prediction
new_data=pd.DataFrame({"TV":[100],"Radio":[50],"Newspaper":[20]})
predicted_sales=model.predict(new_data)
print("Predicted Sales:",predicted_sales)
# Out:
# Predicted Sales: [16.96699408]

# %%
#Confusion Matrix
#Confusion matrix used to evluate classification models
#It is not used to evaluate linear regression models
